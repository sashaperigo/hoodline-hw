# %%
from geopy import geocoders
import geopy.distance
gn = geocoders.GeoNames(username='sperigo')

# %%
cities = ['Canada', "Modi'in", 'Castlegar', 'Arl\xc3\xb6v', 'Nampa', 'Liverpool', 'High Wycombe', 'North Palm Beach', 'Playa Vista', 'Le\xc3\xb3n', 'Scottsdale', 'Palma De Mallorca', 'Gravesend', 'Shirley', 'Waterloo', 'Industry', 'Gizah', 'Tallin', 'New City', 'Ramat Hasharon', 'Anshan', 'Isfiyeh', 'Midview City', 'Libertyville', 'Frisco', 'Alpine', 'Genova', 'Burleigh Heads', 'Sunrise', 'Villanova', 'Z\xc3\xbcrich', 'North Sydney', 'Curitiba', 'Minnetonka', 'Sebastopol', 'Renton', 'Boise', 'Hamilton', 'Sandown', 'Colorado Springs', 'Eindhoven', 'Shunyi', 'Burbank', 'Histon', 'Utrecht', 'Wicklow', 'Ohio', 'Chapelhall', 'Fitchburg', 'San Gwann', 'M\xc3\xbcnster', 'Villefranche-sur-sa\xc3\xb4ne', 'Quezon City', 'Xian', 'Las Vegas', 'Littleborough', 'Framingham', 'Manhattan Beach', 'Scottsboro', 'Lyon', 'Quincy', 'Syosset', 'Cramlington', 'Subiaco', 'Mandaluyong', 'Pasadena', 'Wales', 'Oostkamp', 'Tamworth', 'Broughton Vale', 'Akron', 'North Brunswick', 'Brighton', 'Leiria', 'West Lafayette', 'Bilbao', 'Havelock North', 'Hsinchu', 'Oshakati', 'Villanueva Del Pardillo', 'Oak Ridge', 'Lund', 'Lab\xc3\xa8ge', 'Nunoa', 'Sherman Oaks', 'Hopkinton', 'Antwerp', 'West Palm Beach', 'Tampere', 'Del Mar', 'Eagle', 'Lakewood', 'Feusisberg', 'Qianjiang', 'Hampstead', 'Freiburg Im Breisgau', 'Irving', 'Gardner', 'Edmond', 'Beverly', "Ra'anana", 'Hartford', 'Columbia City', 'Hancock', 'Paterna', 'Dhaka', 'Sioux Falls', 'Aix-en-provence', 'Saskatoon', 'Caledon', 'Billund', 'New Baltimore', 'Valbonne', 'Jinan', 'Aarhus', 'Longview', 'Santa Cruz De Tenerife', 'Newyork', 'Midvale', 'Monroe', 'Monterrey', 'Arlington', 'Newark', 'Sammamish', 'Changzhou', 'Charlottesville', 'Mollet del Vall\xc3\xa8s', 'Gen\xc3\xa8ve', 'Addison', 'Kristiansand', 'Nieuwegein', 'Saint Etienne', 'Limonest', 'Foster City', 'Rochester Hills', 'Pessac', 'Jonesboro', 'Kinloss', 'Hackensack', 'Hickory', 'Clontarf', 'Garching Bei M\xc3\xbcnchen', 'Mohali', 'Marseille', 'Hunan', 'Huizhou', 'Cairo', 'Radnor', 'Fort Worth', 'Naarden', 'Milan', 'Nijmegen', 'Superior', 'Bethesda', 'Frankfort', 'Sant Pere De Ribes', 'Dortmund', 'Glen Innes', 'Evanston', 'Nederweert', 'Dungarpur', 'Jamestown', 'Phnom Penh', 'Guin', 'Newbury', 'Hubei', 'Jogeshwari', 'Chatham', 'Xinjiang', 'Emeryville', 'Salzburg', 'Iowa City', 'Watertown', 'Frankfurt', 'Cambridge', 'Woking', 'Ile-ife', 'Delray Beach', 'Chalfont', 'Sandy', 'Hongo', 'Biatorb\xc3\xa1gy', 'Rancho Santa Fe', 'Kyiv', 'Bengaluru', 'Tredegar', 'Loughborough', 'Chestnut Hill', 'Strasbourg', 'Rehovot', 'Kandivli', 'Barrie', 'Mesa', 'Moskva', 'Markham', 'West Chester', 'Rockville', 'Didcot', 'Gent', '\xc3\x87an', 'Burnaby', 'Summit', 'Charleston', 'Wroclaw', 'Reykjav\xc3\xadk', 'La Reina', 'Croydon', 'Kennebunk', 'Buena Park', 'Aachen', 'Chicago', 'Farmington', 'South Orange', 'Saint Petersburg', 'Pickering', 'Killingworth', 'Yoqne`am `illit', 'Belgrano', 'Charlottetown', 'Malm\xc3\xb6', 'Lincolnshire', 'Suwon', 'Stroud', 'El Segundo', 'Grand Rapids', 'Kittanning', 'Little Falls', 'Chongqing', 'Los Altos', 'Bakersfield', 'Pigeon Forge', 'Jersey City', 'Ar Riyadh', 'Frederick', 'Kiryat Gat', 'Brecksville', 'Jerusalem', 'Saint George', 'Sofia', 'Philippine', 'Selangor', 'Encinitas', 'Lisbon', 'Lisboa', 'Colomiers', 'Copenhagen', 'Worthington', 'S\xc3\xa3o Jos\xc3\xa9 Dos Campos', 'Kiev', 'Saarbr\xc3\xbccken', 'George Town', 'Huawei', 'Santiago', 'Harrisonburg', 'Marmande', 'Coleraine', 'Nantes', 'Donostia-san Sebasti\xc3\xa1n', 'Pembroke', 'Bala Cynwyd', 'Wakefield', 'Rio Rancho', 'Gloucester', 'Moora', 'Fife', 'Frenchtown', 'Washington', 'Andover', 'Chuzhou', 'Jackson', 'Caracas', 'Kempele', 'Anderson', 'Sydney', 'Pasig', 'Snodland', 'Gurgaon', 'G\xc3\xb6teborg', 'West Bridgewater', 'San Antonio', 'Naha', 'Central', 'Jurong West', 'Fuzhou', 'Horsham', 'Bronx', 'Cupertino', 'Stuttgart', 'Stratford', 'Irvington', 'Aberdeen', 'Palm Springs', 'Wollongong', 'Saint Laurent', 'Vadodara', 'Piscataway', 'Gladesville', 'Ireland', 'East Hartford', 'Jiaxing', 'Jiading', 'Mamaroneck', 'Algiers', 'Ximen', 'Tokyo', 'Helsingborg', 'Clermont', 'Anaheim', 'Fayetteville', 'Bozeman', 'Bosmat Tivon', 'Deland', 'Dongguang', 'Worcester', 'Hook', 'Jeddah', 'Cleveland', 'Campbell', 'Tigard', 'Temecula', 'Los Gatos', 'Tianjin', 'Cpu Town Of Hillside Llc', 'Athens', 'Potomac', 'Heidelberg', 'Karlsruhe', 'Mishawaka', 'Voorhees', 'Harrisburg', 'Rochford', 'Budapest', 'Gastonia', 'Sandpoint', 'Seongnam', 'Jakarta', 'Freeport', 'Nanshan', 'Tangerang', 'San Anselmo', 'Bristol', 'Ashland', 'Ballston Spa', 'Spalding', 'Leicester', 'Durango', 'Parma', 'Des Moines', 'Portland', 'Piura', 'Awans', 'Espoo', 'Mysore', 'Thane', 'Glen Allen', 'Shenzhen', 'Yancheng', 'Southborough', 'Tampa', 'East Rockaway', 'Menlo Park', 'Corona', 'Plant City', 'Walnut Creek', 'Fresno', 'Martinsried', 'Wildau', 'Drumcondra', 'Maryland Heights', 'San Marcos', 'Ithaca', 'Warren', 'Milpitas', 'Hillsborough', 'Zhongrong', 'Ayer', 'Fargo', 'Mount Kisco', 'Woodland Hills', 'Edinburgh', 'Saltillo', 'Lee', 'Pittsfield', 'Guilford', 'Gwangju', 'Syracuse', 'Columbia Falls', 'Graz', 'Bodrum', 'Cape Town', 'Hornsyld', 'Luanda', 'Pilisv\xc3\xb6r\xc3\xb6sv\xc3\xa1r', 'Warszawa', 'Montreuil', 'Madison', 'Guangxi', 'Cape Canaveral', 'Westerville', 'Essex', 'Hyattsville', 'Farum', 'Zhuyuan', 'Chemnitz', 'Lugano', 'Dallas', 'Greifswald', 'Changning', 'Meriden', 'Barbar\xc3\xa1', 'Puteaux', 'El Dorado Hills', 'Moravian Falls', 'Gisenyi', 'Firenze', 'Sliema', 'Burghclere', 'Poznan', 'Ames', 'Arr\xc3\xbabal', 'Petaling', 'Golden', 'Southfield', 'Dania', 'Pleasanton', 'Chapel Hill', 'Gaithersburg', 'Prague', 'Townsville', 'Cuarte De Huerva', 'Granada', 'Hudson', 'Kingston', 'Malta', 'Washington Depot', 'Gaza', 'Stralsund', 'Southend-on-sea', 'Cornwall', 'South Jordan', 'Guntur', 'Long Island City', 'Alnwick', 'San Pedro Sula', 'Waxahachie', 'Cremona', 'Wichita', 'Melbourne', 'Vado Ligure', 'Pangyo', 'Park Ridge', 'Monument', 'Sint-niklaas', 'Dalian', 'Alsdorf', 'Arusha', 'Sunderland', 'Szeged', 's-hertogenbosch', 'Dundee', 'Mylapore', 'Ipswich', 'Indiana', 'Louisiana', 'Chennai', 'Columbia', 'Northfield Falls', 'Verona', 'Pedrulha', 'Falmouth', 'El Paso', 'Atlanta', 'Ahmedabad', 'Orem', 'Yishan', 'Oldsmar', 'Budd Lake', 'Solihull', 'Foiano Della Chiana', 'Yemassee', 'Harbin', 'Enniskillen', 'Hampton In Arden', 'Kanpur', 'Laguna Beach', 'Pointe-claire', 'Hereford', 'Weiji', 'Santa Barbara', 'Avenel', 'Novi', 'Bowling Green', 'Burlington', 'Orange', 'Midlothian', 'Sheffield', 'Guangzhou', 'Hefei', 'Kuala Lumpur', 'Southbank', 'Luoyang', 'Honolulu', 'Bayswater', 'Nehalim', 'Grenoble', 'Inchinnan', 'Uniondale', 'Randburg', 'Latham', 'Sunnyvale', 'Guimar\xc3\xa3es', 'San Bruno', 'Friendswood', 'Gampaha', 'Sacramento', 'Azadpur', 'Wixom', 'Chaoyang', 'Clitheroe', 'Lansing', 'Redwood Shores', 'York', 'Australia', 'Sarasota', 'South Bend', 'Needham', 'Netanya', 'Newtown', 'Bray', 'Littleton', 'Orlando', 'Gresik', 'Newcastle Upon Tyne', 'Calabasas', 'Qingdao Shi', 'Pewaukee', 'Montreal', 'Antwerpen', 'North Kingstown', 'Fredonia', 'Lebanon', 'Bath', 'Costa Mesa', 'Chelmsford', 'Livermore', 'Al Khobar', 'Herndon', 'Kicukiro', 'Encino', 'Hod Hasharon', 'Kajaani', 'La Fayette', 'Munich', 'Grand Cayman', 'Lublin', 'Kalmar', 'Arkadelphia', 'Alpharetta', 'Glen Mills', 'Sausalito', 'Cariacica', 'Mississauga', 'Bochum', 'Creve Coeur', 'Prien Am Chiemsee', 'Trento', 'Shandong', 'Ashkelon', 'Panama City Beach', 'Chagrin Falls', 'Pimpama', 'Barnet', 'Zhengzhou', 'Peterborough', 'Winston Salem', 'Pyrmont', 'Mayfair', 'Wyoming', 'Lake Saint Louis', 'Welwyn Garden City', 'Covington', 'Perth', 'Irvine', 'Brookfield', 'Ghana', 'Montbonnot', 'Noida', 'Kirby', 'Manitowoc', 'Delhi', 'Avon', 'Kista', 'Lenexa', 'Norfolk', 'Dki Jakarta', 'Alkmaar', 'Augusta', 'Rome', 'Kenosha', 'Roma', 'Lippstadt', 'Balmain', 'Blackshear', 'Kitchener', 'Kilpauk', 'Bresles', 'North Little Rock', 'Vi\xc3\xb1a Del Mar', 'Latina', 'Charles Town', 'Wangjing', 'Snyder', 'Cookeville', 'Guadalajara', 'Michigan', 'Udine', 'Tifton', 'Richfield', 'Ultimo', 'Miami Beach', 'Rueil-malmaison', 'Lucknow', 'Fornebu', 'Leuven', 'Fort Lee', 'Lake Villa', 'Rio De Janeiro', 'Hauppauge', 'Adelaide', 'Brazil', 'Norwalk', 'Sanford', 'Ontario', 'Merritt Island', 'Blanca', "St. John's", 'Oak Park', 'Altrincham', 'Hollywood', 'San Carlos', 'Estillac', 'Rolling Meadows', 'Burlingame', 'Uppsala', 'Litchfield', 'Bellshill', 'Crawley', 'Falls Church', 'Ouakam', 'Aveiro', 'Nairobi', 'Kalamazoo', 'Colorado', 'Concord', 'Maidenhead', 'Guwahati', 'Hoskote', 'Pelotas', 'Belo Horizonte', 'C\xc3\xb3rdoba', 'Rocklin', 'Sveta Nedelja', 'Jaipur', 'Chantilly', 'Philadelphia', 'Woodridge', 'Maia', 'Danville', 'Fort Myers', 'Naples', 'Torrance', 'Bandra', 'Gurnee', 'Marshfield', 'Mankato', 'Ranelagh', 'Langley', 'Groot-bijgaarden', 'The Valley', 'Boone', 'San Francisco', 'Weston', 'Sturtevant', 'Amsterdam', 'Hummelstown', 'Paphos', 'Kent', 'Lutherville Timonium', 'Medicine Hat', 'Laguna Niguel', 'Hull', 'Kansas', 'Rosenheim', 'Century City', 'Leeds', 'Redlands', 'Pune', 'Paducah', 'Lexington', 'Northfield', 'Guizhou', 'Giussago', 'Ostrava', 'De Pere', 'Folsom', 'Manchester', 'Jursta', 'Trollh\xc3\xa4ttan', 'Rheinbreitbach', 'Pawtucket', 'San Juan', 'Imperial Beach', 'Blackrock', 'Chepstow', 'Seminole', 'Hebei', 'Eb\xc3\xa8ne', 'Berlin', 'Elmhurst', 'Bangalore', 'Tomball', 'North Charleston', 'Kailua Kona', 'Palm Beach Gardens', 'Bainbridge', 'Shenze', 'Sugar Land', 'Lewes', 'Misgav', 'Gisors', 'Guatemala City', 'Owerri', 'Haddonfield', 'Orinda', 'B\xc3\xa8gles', 'Eden Prairie', 'V\xc3\xa4stra Fr\xc3\xb6lunda', 'Xuhui', 'Kwun Tong', 'M\xc3\xbcnchen', 'Whitestone', 'Lokeren', 'El Cajon', 'Cremorne', 'City Of London', 'Millbrae', 'Saint Louis', 'Kiryat Malachi', 'Sharjah', 'Valley Stream', 'Mount Pleasant Mills', 'Braintree', 'Virgin', 'Ghaziabad', 'Park City', 'Dripping Springs', 'Winterthur', 'Venice', 'Mechelen-bovelingen', 'Valencia', 'Chandler', 'Montevideo', 'Shah Alam', 'Palmerston North', 'Nashville', 'P\xc3\xa9cs', 'Dobbs Ferry', 'Plano', 'Beaverton', 'Quebec', 'Peschiera', 'Jyv\xc3\xa4skyl\xc3\xa4', 'Kansas City', 'Barcelona', 'Skelmersdale', 'Rialto', 'Hampton', 'Caesarea', 'Reno', 'Lagos', 'Shoreditch', 'Milwaukee', 'Letterkenny', 'Richland', 'Oslo', 'Provo', 'Zhongshan', 'Santa Rosa', 'Spartanburg', 'Yardley', 'Sterling', 'Sandwich', 'Lod', 'Innsbruck', 'Frederiksberg', 'Newcastle', 'Nuremberg', 'Petah Tiqva', 'Saratoga', 'Fahaheel', 'Pine Bluff', 'Shelton', 'Caldas Da Rainha', 'Belmont', 'Bloomfield', 'Long Beach', 'Troy', 'London', 'Sitrah', 'Newton', 'Auckland', 'India', 'Coralville', 'Lake Mary', 'Kolkata', 'Swansea', 'Vienna', 'College Park', 'Brentwood', 'Essen', 'Blue Mounds', 'Branford', 'Modena', 'Bridgeview', 'Spokane', 'Wilmington', 'San Jose', 'Rootstown', 'Foshan', 'Buea', 'Los Alamos', 'Billerica', 'Hyderabad', '\xc3\x85re', 'Lissabon', 'Zhuhai', 'Tuscaloosa', 'Blaine', 'Guangdong', 'Medell\xc3\xadn', 'Zug', 'Cartago', 'Palo Alto', 'Cerritos', 'St. Petersburg', 'Kormangala', 'Karreb\xc3\xa6ksminde', 'Annecy', 'Ljubljana', 'Rotterdam', 'S\xc3\xa4vedalen', 'Fort Lauderdale', 'Islandia', 'Durban', 'Aliso Viejo', 'Asheville', 'Santa Cruz', 'Binghamton', 'Fort Smith', 'Olathe', 'Englewood', 'New Concord', 'Little Rock', "Be'er Sheva", 'North Augusta', 'Greensboro', 'Doha', 'Shengzhou', 'Cagliari', 'San Juan Capistrano', 'Bentonville', 'Lancaster', 'Groningen', 'Kelowna', 'Yonkers', 'Idaho Falls', 'Braga', 'Norrk\xc3\xb6ping', 'G\xc3\xaeza', 'Combined Locks', 'Sophia Antipolis', 'Simi Valley', 'Ankara', 'Plymouth Meeting', 'Ghent', 'Malvern', 'Ikeja', 'Omaha', 'Ancaster', 'Plymouth', 'Minsk', 'Torun', 'Almaty', 'Chile Chico', 'New Haven', 'New Berlin', 'Chengdu', 'Greenford', 'Lyngby', 'Rosamond', 'Swindon', 'Alachua', 'Rovaniemi', 'Edison', 'Petah Tiqwa', 'The Woodlands', 'Mercer Island', 'Wayne', 'Tel Aviv', 'Alameda', 'Goi\xc3\xa2nia', 'Vantaa', 'Maple Grove', 'Fremont', "Saint Paul's Bay", 'Zapopan', 'Ramat Gan', 'Brno', 'Pennsylvania Furnace', 'Ladson', 'Glamorgan Vale', 'West Valley City', 'Blumenau', 'Link\xc3\xb6ping', 'Holliston', 'Feasterville Trevose', 'Mannheim', 'Bentley', 'Axminster', 'Bundangdong', 'Sumar\xc3\xa9', 'Nottingham', 'Beavercreek', 'Vilnius', 'Wellesley', 'Santa Monica', 'Denver', 'Ho Chi Minh City', 'H\xc3\xb8jbjerg', 'Coral Gables', 'Cracow', 'Stevenage', 'Paramus', 'Pudong', 'Solana Beach', 'Newhouse', 'Neuilly-sur-seine', 'Alderley Edge', 'Newburyport', 'Hattersheim', 'Visby', 'Zurich', 'Clare', 'Northampton', 'Tucson', 'Rancho Cordova', 'Saint Augustine', 'South San Francisco', 'K\xc3\xb6ln', 'Zhenjiang', 'Istanbul', 'Kuwait', 'Mount Pleasant', 'Yogyakarta', 'Canton', 'Richmond', 'Providence', 'Louisville', 'Columbus', "Rosh Ha'ayin", 'Varese', 'Cork', 'Conversano', 'Hong Kong', 'Brasil', 'Wenzhou', 'Sandyford', 'Loveland', 'Guiyang', 'Woburn', 'Notre Dame', 'Roosendaal', 'Yerevan', 'Tartu', 'Toulouse', 'Monza', 'Oklahoma City', 'West Des Moines', 'Valparaiso', 'Peachtree City', 'Scunthorpe', 'Bergamo', 'Wayzata', 'Glasgow', 'Dresden', 'Zagreb', 'Frances', 'Vejle', 'Penmon', 'Tainan', 'Hanover', 'Chattanooga', 'Surco', 'Petaluma', 'Walthamstow', 'Stowmarket', 'Saddle River', 'Pullman', 'Red Bank', 'Silver Spring', 'Fishers', 'Westlake Village', 'Ridgewood', 'Chanhassen', 'Afton', 'Laval', 'Brunswick', 'Esplugas De Llobregat', 'Bangkok', 'Bungoma', 'Marlborough', 'Yangpu', 'Fort Wayne', 'Bielsko-biala', 'Hamburg', 'Essendon', 'Brussels', 'Leesburg', 'Allston', 'Bogot\xc3\xa1', 'Castelldefels', 'Makati', 'Monmouth Junction', 'Taipei', 'Mclean', 'East Lansing', 'Savannah', 'Midhurst', 'Saint-malo', 'Andheri', 'Abbotsford', 'Minnesota City', 'Effingham', 'Osaka', 'Royersford', 'Harare', 'Oldham', 'Tripoli', 'Varsseveld', 'Heusden', 'Reading', 'Szatymaz', 'Hamman-sousse', 'Leiden', 'Everett', 'Ridgefield', 'Kennesaw', 'Florian\xc3\xb3polis', 'Lane Cove', 'Highland Park', 'Nunawading', 'Palos Heights', 'Coimbr\xc3\xa3', 'Redwood City', 'Petaling Jaya', 'West Molesey', 'Belding', 'Boston', 'Kennewick', 'Abeokuta', 'Batavia', 'Herzliyya', 'Dongda', 'Lausanne', 'Corsham', 'Oklahoma', 'Imo', 'Lekki', 'Gilbert', 'Parel', 'Smiths Falls', 'Chevy Chase', 'Trondhjem', 'Belgium', 'Penn Valley', 'Paoli', 'Walled Lake', 'Jakatra', 'Dijon', 'Milano', 'Ottawa', 'Ventura', 'Cyberport', 'Incheon', 'Madurai', 'Chesham', 'Gie\xc3\x9fen', 'Laguna Hills', 'New Orleans', 'Mumbai', 'Baar', 'Glyf\xc3\xa1da', 'Douglas', 'City Of Industry', 'Montr\xc3\xa9al', 'Westport', 'Penzance', 'Dracut', 'Saint Gallen', 'Cluj', 'Sichuan', 'Triangle', 'Kyoto', 'Vineland', 'Conshohocken', 'Amityville', 'Colombo', 'Guildford', 'Bhubaneswar', 'Coventry', 'Changsha', 'Mechanicsville', 'Lafayette', 'Delft', 'Honduras', 'Egypt', 'Armthorpe', 'Nanjing', 'Conifer', 'Lille', 'Binyamina', 'Vanves', 'Wedel', 'Daytona Beach', 'Dartmouth', 'Kirkland', 'Henderson', 'Redmond', 'Courbevoie', 'Tulsa', 'Abu Dhabi', 'Ann Arbor', 'Skretting', 'Srinagar', 'Broomfield', 'Bedford', 'Dublin', 'Oakville', 'Cedar Rapids', 'Antrim', 'Benin City', 'Santa Clarita', 'Chicacao', 'T\xc3\xbcbingen', 'Sint-martens-latem', 'Westlake', 'Minneapolis', 'Telford', 'Salt Lake City', 'Itasca', 'Des Arc', 'Rochester', 'Holzgerlingen', 'Knoxville', 'Issoire', 'Cheyenne', 'Boutersem', 'Yarnton', 'Roissy', 'Valley City', 'Woodside', 'Ludhiana', 'Lehi', 'Osborne', 'Hyannis', 'Marina Del Rey', 'Tehran', 'Southampton', 'Basingstoke', 'Florida', 'Oranmore', 'Tustin', 'Round Rock', 'Richmond Upon Thames', 'Mordialloc', 'Bellevue', 'Fulton', 'Sidney', 'Panama', 'Oneonta', 'Bellaire', 'Gibraltar', 'Santa Ana', 'Depok', 'Saltaire', 'Bethel', 'Cary', 'Farnborough', 'Haryana', 'Quanzhou', 'Jintan', 'California', 'Lubbock', 'Brooklyn Park', 'Princeton', 'Maitland', 'Stockholm', 'Whistler', 'Fairfax', 'Darmstadt', 'Ellicott City', '\xc3\x96stersund', 'Garner', 'Salem', 'Niagara', 'Cardiff By The Sea', 'Heerenveen', 'Froland', 'Pancevo', 'Italy', 'Horsens', 'Bismarck', 'Faridabad', 'Beaconsfield', '\xc3\x96rebro', 'Bothell', 'San Clemente', 'Norwich', 'Mill Valley', 'Melbourn', 'Wuhan', 'Sainte-genevi\xc3\xa8ve-des-bois', 'Taguig', 'Waukesha', 'Fort Washington', 'Wan Chai', 'Gosforth', 'Henley In Arden', 'Raleigh', 'Nancy', 'Glendale', 'Reston', 'Weifang', 'Bincombe', 'Woodbridge', 'Minhang', 'Albany', 'Plainview', 'Washougal', 'Daxing', 'Castle Hayne', 'Champaign', 'North Pole', 'Luzern', 'Devon', 'Berkeley', 'Kidlington', 'Esch-sur-alzette', 'University Park', 'Milton Keynes', 'Alpha', 'Dunedin', 'Waltham', 'La France', 'Alexandria', 'Cincinnati', 'Guelph', 'Clearwater', 'Herning', 'San Luis Obispo', 'Belconnen', 'Manila', 'Targu-mures', 'Palaiseau', 'M\xc3\xa1laga', 'Napa', 'Siena', 'Murfreesboro', 'Seoul', 'Pittsburgh', 'Moscow', 'Albuquerque', 'Nyack', 'Anjou', 'Colleyville', 'Gosselies', 'Southport', 'Karachi', 'Slovenska Bistrica', 'Suhr', 'Telluride', 'Davis', 'New Delhi', 'Olympia Fields', 'Essonnes', 'Elizabethtown', 'Greencastle', 'Marylebone', 'Rennes', 'Midland', 'Tirat Carmel', 'Manama', 'Skillman', 'Wills Point', 'Boulder', 'Norman', 'Unterf\xc3\xb6hring', 'Normal', 'Baton Rouge', 'Newport Beach', 'Puerto Rico', 'Dempocho-kita', 'Boca Raton', 'V\xc3\xa9lizy-villacoublay', 'Odense', 'Osceola', 'General Lagos', 'Franklin', 'Austin', 'Enschede', 'Beijing', 'Pacific Palisades', 'Murray', 'Goleta', 'Vaajakoski', 'Kanagawa', 'Phoenix', 'Yverdon-les-bains', 'Manhattan', 'Am\xc3\xa9s', 'Culver City', 'Dongcheng', 'Ramona', 'Finchingfield', 'Changchun', 'Sisters', 'Gold Coast', 'Westmont', 'Stanford', 'Studio City', 'Waardenburg', 'Birkenhead', 'Longwood', 'Derby', 'Eau Claire', 'Bishops Stortford', 'Leipzig', 'Westlands', 'Stamford', 'Cardiff', 'Oakland', 'Secaucus', 'Warsaw', 'Bologna', 'Ellon', 'Basel', 'West Hollywood', 'Leawood', 'South Pasadena', 'Scoresby', 'Montorn\xc3\xa9s Del Vall\xc3\xa9s', 'Seocho', 'Mont-saint-guibert', 'Richmond Hill', 'Kochi', 'Waynesboro', 'Boulogne-billancourt', 'Bradenton', 'Holland', 'Biberach An Der Ri\xc3\x9f', 'Silverdale', 'Accra', 'Saint-jean-bonnefonds', 'Chico', 'Medford', 'Charlotte', 'Vaasa', 'Brisbane', 'Edmonton', 'Johannesburg', 'La Rinconada', 'Seattle', 'Turku', 'Wanzhou', 'Allentown', 'Garden Grove', 'Herzlia B', 'Harju', 'Wamego', 'San Rafael', 'Qingpu', 'San Mateo', 'Linz', 'San Diego', 'Haerbin', 'Maastricht', 'Tucker', 'Butte', 'Israel\xc3\xa2ndia', 'Missoula', 'Pescara', '\xc3\x85lesund', 'Tranent', 'Trumbull', 'Eatontown', 'Carlsbad', 'Ningbo', 'Greenwich', 'Porsgrunn', 'Macei\xc3\xb3', 'Yangon', 'Sarona', 'Indianapolis', 'Guindy', 'Mountain View', 'Armadale', 'Solt', 'Memphis', 'Galway', 'Ridgeway', 'Denmark', 'Staten Island', 'Mount Wolf', 'Donegal', 'Granada Hills', 'West Burton', 'Minato', 'Aventura', 'Birmingham', 'H\xc3\xb8rsholm', 'Halifax', 'Nevada', 'Campina', 'Surabaya', 'Parramatta', 'Huntington Woods', 'Annapolis', 'Liding\xc3\xb6', 'Sariyer', 'Warrington', 'St Louis', 'Glenrothes', 'Stirling', 'Garcia', 'Daresbury', 'Huntington Beach', 'Indore', 'Nashua', 'Dalkey', 'Dalston', 'Tennessee', 'Harwell', 'Warrendale', 'Rang-du-fliers', 'V\xc3\xa4ster\xc3\xa5s', 'Wilson', 'Hongqiao', 'Redondo Beach', 'Haidian', 'Walpole', 'Herzliya', 'Warwick', 'Beirut', 'Beeston', 'American Fork', 'Thousand Oaks', 'Porto', 'Dubai', 'Miami', 'Huangpu', 'Ibb', 'Kineton', 'Gateshead', 'Abidjan', 'Beit Yanai', 'Darien', 'Plan-les-ouates', 'Aracaju', 'North Royalton', 'Port Hueneme Cbc Base', 'Gdynia', 'Liberty', 'No\xc3\xa1in', 'Borgen', 'Debrecen', 'Hayward', 'Claremont', 'China', 'Chino', 'Maple Ridge', 'Haifa', 'East Peoria', 'Matawan', 'Neptune', 'Natick', 'Iver', 'Hangzhou', 'Buffalo', 'Bulgaria', 'Shipston On Stour', 'Madrid', 'Dayton', 'Middleton', 'Kowloon City', 'Taian', 'Wadsworth', 'Mexico City', 'Belfast', 'Newcastle Under Lyme', 'Flushing', 'Cologne', 'Elk River', 'Dongguan', 'Saint Asaph', 'Heerlen', 'Nasr City', 'Botafogo', 'Lincoln', 'Helsinki', 'Laconia', 'Macclesfield', 'Bordeaux', 'Bolton', 'Hastings', 'University Center', 'New York', 'Lima', 'Bergen', 'Thornhill', 'Mt Pleasant', 'Westminster', 'V\xc3\xa4xj\xc3\xb6', 'Knutsford', 'Pueblo', 'Sz\xc3\xa9kesfeh\xc3\xa9rv\xc3\xa1r', 'Storm Lake', 'Kecskem\xc3\xa9t', 'Maroubra', 'Puebla', 'Bangor', 'Logro\xc3\xb1o', 'La Jolla', 'Suzhou', 'Ottumwa', 'Montpellier', 'Schenectady', 'Beverly Hills', 'Bend', 'Paris', 'North York', 'Fengxian', 'Morristown', 'Port Harcourt', 'Abuja', 'Independence', 'Tavares', 'Northwich', 'Southbridge', 'Treviso', 'Ottobrunn', 'Greenwood Village', 'Hildesheim', 'Schlieren', 'Aalborg', 'Gwalior', 'Newport', 'Saint Catharines', 'Or Yehuda', 'Lusby', 'Danvers', 'Camden', 'Unterhaching', 'Darlington', 'Sparta', 'San Leandro', 'Amman', 'Poway', 'Aurora', 'Squamish', 'Powai', 'Lockerbie', 'Los Angeles', 'Greenbelt', 'Xiamen', '\xc3\x89vry', 'Carlinville', 'Blacksburg', 'Alicante', 'Wuxi', 'Krak\xc3\xb3w', 'Kathmandu', 'Pompano Beach', 'Portsmouth', 'Putuo', 'Santa Fe', 'Middlesbrough', 'Modesto', 'Centennial', 'Tacoma', 'Heliopolis', 'Vaughan', 'Elche', 'Lappeenranta', 'Santa Clara', 'Fredericton', 'Hanoi', 'Luxembourg', 'St. Helens', 'Widnes', 'Floyds Knobs', 'Purfleet', 'College Point', 'Turin', 'Letchworth', 'Birkirkara', 'Brooklyn', 'Mansfield', 'Gyor', 'Trondheim', 'Germantown', 'Toronto', 'Yuhang', 'Riga', 'Saint Paul', 'Ponte Vedra Beach', 'Wellington', 'Stockton-on-tees', 'Livingston', 'Kfar Saba', 'Richardson', 'Oulu', 'Capelle Aan Den Ijssel', 'Sha Tin', 'Koerich', 'Bethlehem', 'Taiwan', 'Somerville', 'Illkirch', 'Victoria Valley', 'Shanghai', 'Plantation', 'Tallinn', 'S\xc3\xa3o Paulo', 'Snoqualmie', 'Gothenburg', 'Lowell', 'Nantong', 'Huntsville', 'Buenos Aires', 'Excelsior', 'Beerse', 'San Ramon', 'Springfield', 'Oxford', 'West Bromwich', 'Qingdao', 'Coalinga', 'Baldwinsville', 'Neuch\xc3\xa2tel', 'Deerfield Beach', 'Guaynabo', 'Little Chesterford', 'Carmel', 'Dulles', 'Houston', 'Geneva', 'Upplands-v\xc3\xa4sby', 'Spring', 'North Reading', 'Sandston', 'Clemson', 'Veszpr\xc3\xa9m', 'Exton', 'Ecublens', 'Guipavas', 'Bannockburn', 'Bloomington', 'Milford', 'College Station', 'Victoria', 'Ness Ziona', 'Kampala', 'Burgos', 'Collierville', 'Plainsboro', 'Boldesti-scaeni', 'Christchurch', 'Camberley', 'Jamaica', 'England', 'Casablanca', 'Hennigsdorf', 'Durham', 'Visakhapatnam', 'Mont Kigali', 'Westwood', 'Shefayim', 'Oxton', 'Orono', 'Mineola', 'Gainesville', 'Mason', 'Heslington', 'Bromont', 'Seville', 'Banbury', 'Eugene', 'Draper', 'Singapore', 'Dezhou', 'Tanggu', 'Brockton', 'Holmfirth', 'Mooresville', 'Morrisville', 'Shijiazhuang', 'Saint-bonnet-de-vieille-vigne', 'Santa Catarina', 'Chester', 'Bathurst', 'Longmont', 'Aksaray', 'Maputo', '\xc3\x81vila', 'Fort Collins', 'Oak Creek', 'California City', 'Land\xc3\xb6n', 'Japan', 'Wong Tai Sin', 'Roselle', 'Issy-les-moulineaux', 'Zionsville', 'Greenville', 'Woodstock', 'Gabrovo', 'Port Credit', 'Dundas', 'Calgary', 'Nakhon Ratchasima', 'Stra\xc3\x9fe', 'Basking Ridge', 'Blackheath', 'Baltimore', 'Wildpoldsried', 'Kissimmee', 'Rocky Hill', 'Ambler', 'Davison', 'Levallois-perret', 'Torres Novas', 'Hutchinson', 'Detroit', 'Lake Forest', 'Okemos', 'Englewood Cliffs', 'Kusnacht', 'Chelsea', 'Bucharest', 'K\xc3\xa9tp\xc3\xb3', 'The Hague', 'Walsall', 'Greeley', 'Riyadh', 'Neuhausen Am Rheinfall', 'L\xc3\xbcdenscheid', 'Jiangshan', 'Longgang', 'Springdale', 'Rye', 'Cirencester', 'Vancouver', 'Las Condes', 'Wimbledon', 'Northridge', 'Tempe', 'Utah', 'Sylmar', 'Marie', 'Jacksonville', 'Milton', 'Barrington', 'Huangshan', "Giv'atayim", 'Pullach', 'Hungerford', 'Melville', 'Dover', 'Abingdon', 'Baoan', 'Roswell', 'Songjiang', 'Spanish', 'Mont\xc3\xa9vrain', 'Augsburg']

# %%
sf = gn.geocode('San Francisco')
sf = (sf.latitude, sf.longitude)
closeby = []
for city in cities:
    try:
        location = gn.geocode(city)
        if location == None:
            continue
        coords = (location.latitude, location.longitude)
        distance = geopy.distance.distance(sf, coords).miles
        #print distance.miles
        #print type(distance.miles)
        #print (distance.miles < 75)
        if (distance < 75) == True:
            print city
            #closeby.add(city)
    except:
        continue
print closeby
# Out:
# Foster City
# Emeryville
# Los Altos
# Cupertino
# Los Gatos
# Menlo Park
# Walnut Creek
# Milpitas
# Pleasanton
# Sunnyvale
# Redwood Shores
# Livermore
# Sausalito
# Burlingame
# San Francisco
# Orinda
# Millbrae
# Palo Alto
# Alameda
# Petaluma
# Redwood City
# Mill Valley
# Berkeley
# Napa
# Stanford
# Oakland
# San Mateo
# Hayward
# San Leandro
# []
